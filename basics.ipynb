# %% [markdown]
# # DCGAN

# %% [markdown]
# GANS are very sensitive to hyperparameters

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Generator
# input is noise

# %% [markdown]
# ![screenshot-www.youtube.com-2024.05.06-23_25_51.png](attachment:screenshot-www.youtube.com-2024.05.06-23_25_51.png)

# %% [markdown]
# # Discrimiator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
