# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# making low resolution to high resolution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
